# %%
import torch
from torch.utils.data import  DataLoader,TensorDataset
import pandas as pd

import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error as MAE
from sklearn.metrics import mean_absolute_percentage_error as MAPE
from sklearn.preprocessing import MinMaxScaler
import torch.nn as nn
from sklearn.model_selection import train_test_split
import category_encoders as ce
import torch

from ray import tune

from ray.tune.schedulers import ASHAScheduler
from sklearn.metrics import r2_score
import numpy as np
import os
from sklearn.model_selection import GridSearchCV
import xgboost as xg
from sklearn.preprocessing import normalize
from sklearn.metrics import mean_squared_error as MSE

from torch.optim.lr_scheduler import StepLR

# %%
df = pd.read_excel("house_price_without_categorical.xlsx",index_col=0)

# %%
categorical_columns = ['Neighborhood',"District","Usage","Heat_type","Floor"]

# %%
Y = df["Price"].values


X = df.drop(columns=["Price"])

# %%
df
# Out:
#        District   Neighborhood  Num_Of_Room   Area        Floor  Age  \
# 0       Gölbaşı        Hacılar            9  550.0  first floor    4
# 1      Keçiören          Etlik            4  145.0   interstage   16
# 2       Çankaya         Birlik            8  340.0   interstage   18
# 3      Keçiören          Etlik            4  110.0     basement   25
# 4       Çankaya  Keklik Pınarı            4  120.0   interstage   26
# ...         ...            ...          ...    ...          ...  ...
# 20055   Çankaya           Emek            6  180.0    top floor   25
# 20056   Polatlı          Zafer            7  340.0    top floor   11
# 20057   Çankaya    Yıldızevler            4  155.0   interstage   23
# 20058  Keçiören     Bağlarbaşı            5  215.0   interstage    8
# 20059   Çankaya       100. Yıl            4  125.0  first floor   40
#
#       Heat_type  Apt_Floor  Credit_Eli  Items  Num_of_Bath        Usage  \
# 0         Kombi          3           1      0            6          Boş
# 1         Kombi          4           1      0            2          Boş
# 2         Kombi          4           1      0            3          Boş
# 3         Kombi          3           1      0            1  Mülk Sahibi
# 4         Kombi         10           1      0            1          Boş
# ...         ...        ...         ...    ...          ...          ...
# 20055     Kombi          4           1      1            1          Boş
# 20056     Kombi          4           1      0            2  Mülk Sahibi
# 20057   Merkezi          4           1      0            2          Boş
# 20058     Kombi         10           1      0            2          Boş
# 20059   Merkezi          3           1      0            1     Kiracılı
#
#           Price
# 0      17700000
# 1       2790000
# 2       4450000
# 3       1249000
# 4       2445000
# ...         ...
# 20055   4500000
# 20056   1395000
# 20057   4750000
# 20058   4250000
# 20059   2250000
#
# [20060 rows x 13 columns]

# %%
Q1 = np.percentile(Y, 25)
Q3 = np.percentile(Y, 75)
IQR = Q3 - Q1


lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

mask = (Y > lower_bound) & (Y < upper_bound)


df_filtered = df[mask]

# %%
df_filtered
# Out:
#        District   Neighborhood  Num_Of_Room   Area        Floor  Age  \
# 1      Keçiören          Etlik            4  145.0   interstage   16
# 2       Çankaya         Birlik            8  340.0   interstage   18
# 3      Keçiören          Etlik            4  110.0     basement   25
# 4       Çankaya  Keklik Pınarı            4  120.0   interstage   26
# 5       Çankaya           Emek            5  147.0   interstage   30
# ...         ...            ...          ...    ...          ...  ...
# 20055   Çankaya           Emek            6  180.0    top floor   25
# 20056   Polatlı          Zafer            7  340.0    top floor   11
# 20057   Çankaya    Yıldızevler            4  155.0   interstage   23
# 20058  Keçiören     Bağlarbaşı            5  215.0   interstage    8
# 20059   Çankaya       100. Yıl            4  125.0  first floor   40
#
#       Heat_type  Apt_Floor  Credit_Eli  Items  Num_of_Bath        Usage  \
# 1         Kombi          4           1      0            2          Boş
# 2         Kombi          4           1      0            3          Boş
# 3         Kombi          3           1      0            1  Mülk Sahibi
# 4         Kombi         10           1      0            1          Boş
# 5       Merkezi         11           1      0            1     Kiracılı
# ...         ...        ...         ...    ...          ...          ...
# 20055     Kombi          4           1      1            1          Boş
# 20056     Kombi          4           1      0            2  Mülk Sahibi
# 20057   Merkezi          4           1      0            2          Boş
# 20058     Kombi         10           1      0            2          Boş
# 20059   Merkezi          3           1      0            1     Kiracılı
#
#          Price
# 1      2790000
# 2      4450000
# 3      1249000
# 4      2445000
# 5      4100000
# ...        ...
# 20055  4500000
# 20056  1395000
# 20057  4750000
# 20058  4250000
# 20059  2250000
#
# [18979 rows x 13 columns]

# %%
Y = df_filtered["Price"]


X = df_filtered.drop(columns=["Price"])

# %%
X
# Out:
#        District   Neighborhood  Num_Of_Room   Area        Floor  Age  \
# 1      Keçiören          Etlik            4  145.0   interstage   16
# 2       Çankaya         Birlik            8  340.0   interstage   18
# 3      Keçiören          Etlik            4  110.0     basement   25
# 4       Çankaya  Keklik Pınarı            4  120.0   interstage   26
# 5       Çankaya           Emek            5  147.0   interstage   30
# ...         ...            ...          ...    ...          ...  ...
# 20055   Çankaya           Emek            6  180.0    top floor   25
# 20056   Polatlı          Zafer            7  340.0    top floor   11
# 20057   Çankaya    Yıldızevler            4  155.0   interstage   23
# 20058  Keçiören     Bağlarbaşı            5  215.0   interstage    8
# 20059   Çankaya       100. Yıl            4  125.0  first floor   40
#
#       Heat_type  Apt_Floor  Credit_Eli  Items  Num_of_Bath        Usage
# 1         Kombi          4           1      0            2          Boş
# 2         Kombi          4           1      0            3          Boş
# 3         Kombi          3           1      0            1  Mülk Sahibi
# 4         Kombi         10           1      0            1          Boş
# 5       Merkezi         11           1      0            1     Kiracılı
# ...         ...        ...         ...    ...          ...          ...
# 20055     Kombi          4           1      1            1          Boş
# 20056     Kombi          4           1      0            2  Mülk Sahibi
# 20057   Merkezi          4           1      0            2          Boş
# 20058     Kombi         10           1      0            2          Boş
# 20059   Merkezi          3           1      0            1     Kiracılı
#
# [18979 rows x 12 columns]

# %%
encoder = ce.TargetEncoder(cols=categorical_columns)
X_encoded = encoder.fit_transform(X, Y)

# %%
X_encoded
# Out:
#            District  Neighborhood  Num_Of_Room   Area         Floor  Age  \
# 1      1.869813e+06  1.992179e+06            4  145.0  2.168055e+06   16
# 2      2.574058e+06  2.846984e+06            8  340.0  2.168055e+06   18
# 3      1.869813e+06  1.992179e+06            4  110.0  1.286913e+06   25
# 4      2.574058e+06  2.481640e+06            4  120.0  2.168055e+06   26
# 5      2.574058e+06  2.931228e+06            5  147.0  2.168055e+06   30
# ...             ...           ...          ...    ...           ...  ...
# 20055  2.574058e+06  2.931228e+06            6  180.0  2.067276e+06   25
# 20056  1.099797e+06  1.136295e+06            7  340.0  2.067276e+06   11
# 20057  2.574058e+06  2.598996e+06            4  155.0  2.168055e+06   23
# 20058  1.869813e+06  1.502789e+06            5  215.0  2.168055e+06    8
# 20059  2.574058e+06  2.410263e+06            4  125.0  1.549521e+06   40
#
#           Heat_type  Apt_Floor  Credit_Eli  Items  Num_of_Bath         Usage
# 1      1.841436e+06          4           1      0            2  2.003629e+06
# 2      1.841436e+06          4           1      0            3  2.003629e+06
# 3      1.841436e+06          3           1      0            1  2.039964e+06
# 4      1.841436e+06         10           1      0            1  2.003629e+06
# 5      2.572097e+06         11           1      0            1  1.975982e+06
# ...             ...        ...         ...    ...          ...           ...
# 20055  1.841436e+06          4           1      1            1  2.003629e+06
# 20056  1.841436e+06          4           1      0            2  2.039964e+06
# 20057  2.572097e+06          4           1      0            2  2.003629e+06
# 20058  1.841436e+06         10           1      0            2  2.003629e+06
# 20059  2.572097e+06          3           1      0            1  1.975982e+06
#
# [18979 rows x 12 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_encoded.values, Y.values, test_size=0.2, random_state=42)

# %%
scaler_X = MinMaxScaler()
scaler_Y = MinMaxScaler(feature_range=(0,1))
X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.transform(X_test)
Y_train_scaled = scaler_Y.fit_transform(y_train.reshape(-1,1))
Y_test_scaled = scaler_Y.transform(y_test.reshape(-1,1))

# %%
Y_train_scaled
# Out:
# array([[0.59006203],
#        [0.43478249],
#        [0.3312628 ],
#        ...,
#        [0.31055886],
#        [0.28778453],
#        [0.5983436 ]])

# %%
X_train_tensor = torch.from_numpy(X_train_scaled).float()
y_train_tensor = torch.from_numpy(Y_train_scaled).float()
X_test_tensor = torch.from_numpy(X_test_scaled).float()
y_test_tensor = torch.from_numpy(Y_test_scaled).float()

# %%
y_test_tensor = y_test_tensor.squeeze(1)

# %%
y_test_tensor
# Out:
# tensor([0.2795, 0.4037, 0.3518,  ..., 0.9265, 0.1418, 0.5383])

# %%
X_train_tensor.shape
# Out:
# torch.Size([15183, 12])

# %%
y_train_tensor = y_train_tensor.squeeze(1)

# %%
y_train_tensor
# Out:
# tensor([0.5901, 0.4348, 0.3313,  ..., 0.3106, 0.2878, 0.5983])

# %%
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
test_dataset = TensorDataset(X_test_tensor, y_test_tensor)

# %%
class AdaptiveTanh(torch.nn.Module):
    def __init__(self, init_alpha =0.9, init_beta=0.1):
        super(AdaptiveTanh, self).__init__()
        self.alpha = torch.nn.Parameter(torch.tensor(init_alpha))
        self.beta = torch.nn.Parameter(torch.tensor(init_beta))
    def forward(self, x):
        return torch.tanh(self.alpha*x + self.beta) 



class Net(nn.Module):
    def __init__(self,L1,L2,L3,L4):
        super(Net,self).__init__()
  
        self.layers = nn.Sequential(
      nn.Linear(12,L1),
      AdaptiveTanh(),
      nn.Linear(L1,L2),
      AdaptiveTanh(),
      nn.Linear(L2,L3),
      AdaptiveTanh(),
      nn.Linear(L3,L4),
      AdaptiveTanh(),
      nn.Linear(L4,1),
    )
    def forward(self, x):
        return self.layers(x)

# %%
def train(dataloader,model,loss_fn,optimizer):
    
    model.train()
    running_loss = 0

    for batch,(x,y) in enumerate(dataloader):

        
        
        optimizer.zero_grad()
        output = model(x) 
        loss   = loss_fn(output.squeeze(),y)
        loss.backward()
        optimizer.step()
        running_loss += loss
        
    
    avg_loss = running_loss/len(dataloader) 
    

    
    return avg_loss

# %%
def validate(dataloader,model,loss_fn):

    
    model.eval() 
    running_loss = 0
    
    with torch.no_grad(): 
        
        for (x,y) in dataloader:
           
            output        = model(x)
            loss          = (loss_fn(output.squeeze(),y))
            
            running_loss += loss

    avg_loss = running_loss/len(dataloader)
      
    
    return avg_loss

# %%
model = Net(16,16,8,8)
loss_fn   = nn.MSELoss() 
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
nb_epochs = 1000
batch_size = 128

scheduler = StepLR(optimizer, step_size=200, gamma=0.5)

# %%
train_dataloader = DataLoader(train_dataset, batch_size=batch_size , shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size , shuffle=False)

# %%
train_losses = []
valid_losses = []
train_loses_for_plot = []

for epoch in range(nb_epochs):
    
    

    train_loss = train(train_dataloader,model,loss_fn,optimizer)
    train_losses.append(train_loss)
    valid_loss = validate(test_dataloader,model,loss_fn) 
    valid_losses.append(valid_loss)
    scheduler.step()
    if epoch % 100 == 0:
        print(f"Epoch : {epoch} train loss :{train_loss}  test loss : {valid_loss}  ")
# Out:
# Epoch : 0 train loss :0.02013997919857502  test loss : 0.013551294803619385
# Epoch : 100 train loss :0.009492808021605015  test loss : 0.009671361185610294
# Epoch : 200 train loss :0.008409477770328522  test loss : 0.009315233677625656
# Epoch : 300 train loss :0.008160454221069813  test loss : 0.010033490136265755
# Epoch : 400 train loss :0.007808107882738113  test loss : 0.009358301758766174
# Epoch : 500 train loss :0.007729552686214447  test loss : 0.009245412424206734
# Epoch : 600 train loss :0.007506633177399635  test loss : 0.009333834983408451
# Epoch : 700 train loss :0.007430548779666424  test loss : 0.009435080923140049
# Epoch : 800 train loss :0.0073279510252177715  test loss : 0.009323503822088242
# Epoch : 900 train loss :0.0073058707639575005  test loss : 0.009402102790772915

# %%
with torch.no_grad():
    
    y_pred_tensor = model(X_test_tensor)
    y_pred_scaled = y_pred_tensor.numpy().squeeze()


y_pred = scaler_Y.inverse_transform(y_pred_scaled.reshape(-1, 1)).squeeze()
y_test_unscaled = scaler_Y.inverse_transform(Y_test_scaled).squeeze()
r2 = r2_score(y_test_unscaled, y_pred)
print(f"R2 score: {r2:.4f}")


plt.figure(figsize=(10, 6))
plt.scatter(y_test_unscaled, y_pred, alpha=0.5)
plt.xlabel("Real Values")
plt.ylabel("Predicted Values")
plt.title("Predicted vs. Real Values (logarithmic)")


plt.xscale("log")
plt.yscale("log")


max_value = max(max(y_test_unscaled), max(y_pred))
plt.plot([1, max_value], [1, max_value], color="red", linestyle="--")
plt.show()
# Out:
# R2 score: 0.7399

# %%
import numpy as np
from scipy import stats
model.eval()




z_scores = np.abs(stats.zscore(y_test))


threshold = 2


mask = (z_scores < threshold)


y_test_filtered = y_pred[mask]
y_pred_filtered = y_test_unscaled[mask]

plt.figure(figsize=(10, 6))
plt.scatter(y_test_filtered, y_pred_filtered, alpha=0.5)
plt.xlabel("Real Values (filtered)")
plt.ylabel("Predicted Values")
plt.title("Predicted vs. Real Values (logarithmic)")


plt.xscale("log")
plt.yscale("log")


min_value_filtered = min(min(y_test_filtered), min(y_pred_filtered))
max_value_filtered = max(max(y_test_filtered), max(y_pred_filtered))
plt.plot([min_value_filtered, max_value_filtered], [min_value_filtered, max_value_filtered], color="red", linestyle="--")

plt.show()

# %%
xgb = xg.XGBRegressor()

param_grid = {
'n_estimators': [1000],
'learning_rate': [0.01],
'max_depth': [5,6,7,8],
'min_child_weight': [1,3,5],
'subsample': [0.5,1.0],
'colsample_bytree': [0.5, 1.0],
'gamma': [ 0.1, 0.2],
'reg_alpha': [0.1,0.2,0.5],
'reg_lambda': [1, 2],
"early_stopping_rounds":[20]
}


grid_search = GridSearchCV(
estimator=xgb,
param_grid=param_grid,
scoring='neg_mean_squared_error',
n_jobs=-1,
cv=2,
verbose=4
)


grid_search.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        verbose=False)       
best_model = grid_search.best_estimator_    

best_model.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        verbose=False)
y_pred_train = best_model.predict(X_train)
y_pred_test = best_model.predict(X_test)
mse_test = MSE(y_test, y_pred_test)
r2 = r2_score(y_test, y_pred_test)

print(f"R2 score  : {r2}")
# Out:
# Fitting 2 folds for each of 576 candidates, totalling 1152 fits
# R2 score  : 0.812904533907695

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred_test, alpha=0.5)
plt.xlabel("Real Values")
plt.ylabel("Predicted Values")
plt.title("Predicted vs. Real Values (logarithmic)")


plt.xscale("log")
plt.yscale("log")


min_value = min(min(y_test), min(y_pred_test))
max_value = max(max(y_test), max(y_pred_test))
plt.plot([min_value, max_value], [min_value, max_value], color="red", linestyle="--")

plt.show()

# %%
import numpy as np
from scipy import stats


z_scores = np.abs(stats.zscore(y_test))


threshold = 2


mask = (z_scores < threshold)

y_test_filtered = y_test[mask]
y_pred_filtered = y_pred_test[mask]

plt.figure(figsize=(10, 6))
plt.scatter(y_test_filtered, y_pred_filtered, alpha=0.5)
plt.xlabel("Real Values (filtered)")
plt.ylabel("Predicted Values")
plt.title("Predicted vs. Real Values (logarithmic)")


plt.xscale("log")
plt.yscale("log")

min_value_filtered = min(min(y_test_filtered), min(y_pred_filtered))
max_value_filtered = max(max(y_test_filtered), max(y_pred_filtered))
plt.plot([min_value_filtered, max_value_filtered], [min_value_filtered, max_value_filtered], color="red", linestyle="--")

plt.show()

# %%
##xgboost overall results
mse_xgboost =  MSE(y_test, y_pred_test)
r2_xgboost =  r2_score(y_test, y_pred_test)
mape_xgboost = MAPE(y_test, y_pred_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_squared_log_error, mean_absolute_percentage_error


mae = mean_absolute_error(y_test, y_pred_test)


mse = mean_squared_error(y_test, y_pred_test)


rmse = mean_squared_error(y_test, y_pred_test, squared=False)


msle = mean_squared_log_error(y_test,y_pred_test)


mape = mean_absolute_percentage_error(y_test, y_pred_test)


r2 = r2_score(y_test, y_pred_test)

# %%
performance_data = {
    'Metric': ['Mean Absolute Error (MAE)', 'Mean Squared Error (MSE)', 'Root Mean Squared Error (RMSE)', 'Mean Squared Log Error (MSLE)', 'Mean Absolute Percentage Error (MAPE)', 'R-squared'],
    'Value': [mae, mse, rmse, msle, mape, r2]
}


performance_df = pd.DataFrame(performance_data)

print(performance_df)
# Out:
#                                   Metric         Value
# 0              Mean Absolute Error (MAE)  2.814391e+05
# 1               Mean Squared Error (MSE)  1.578075e+11
# 2         Root Mean Squared Error (RMSE)  3.972499e+05
# 3          Mean Squared Log Error (MSLE)  1.340376e-01
# 4  Mean Absolute Percentage Error (MAPE)  3.820272e+02
# 5                              R-squared  8.129045e-01

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_squared_log_error, mean_absolute_percentage_error

mae = mean_absolute_error(y_test, y_pred_test)


mse = mean_squared_error(y_test, y_pred_test)

rmse = mean_squared_error(y_test, y_pred_test, squared=False)

msle = mean_squared_log_error(y_test,y_pred_test)


mape = mean_absolute_percentage_error(y_test, y_pred_test)


r2 = r2_score(y_test, y_pred_test)
# Out:
# 164428850435.9716
